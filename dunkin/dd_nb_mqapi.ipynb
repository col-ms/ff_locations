# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# %%
bbox_ranges = [
    '24.00,-85.00,49.00,-125.00',
    '24.00,-85.00,49.50,-80.00',
    '24.00,-80.00,49.50,-76.25',
    '24.00,-76.25,49.50,-73.00',
    '24.00,-73.00,49.50,-69.50',
    '24.00,-69.50,49.50,-66.00',
    '50.70,-169.30,71.70,-140.00',
    '15.00,-179.00,29.00,-154.00'
]

base_url = 'http://www.mapquestapi.com/search/v2/rectangle?'
key = '4XWxa4hnzMheytBGszWEWqoBPwzLk4wI'

# %%
for bb in bbox_ranges:
    
    params = {
        'key': key,
        'boundingBox': bb,
        'units': 'm',
        'ambiguities': 'ignore',
        'maxMatches': '4000',
        'outFormat': 'json',
        'hostedData': 'mqap.33454_DunkinDonuts'
    }

    get_result = requests.get(url = base_url, params = params)

    print(type(get_result))
# Out:
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>

# %%
contents = json.dumps(str(get_result.content)[2:-1], indent = 4, separators=(". ", " = "))

# %%
type(contents)
# Out:
# str

# %%
dict = json.loads(contents)
df2 = pd.DataFrame.from_dict(dict, orient = 'index')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\colli\Documents\Github Repos\ff_locations\dd_nb.ipynb Cell 6' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/colli/Documents/Github%20Repos/ff_locations/dd_nb.ipynb#ch0000011?line=0'>1</a> dict = json.loads(contents)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/colli/Documents/Github%20Repos/ff_locations/dd_nb.ipynb#ch0000011?line=1'>2</a> df2 = pd.DataFrame.from_dict(dict, orient = 'index')
#
# File c:\Users\colli\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1666, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    <a href='file:///c%3A/Users/colli/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=1662'>1663</a> if orient == "index":
#    <a href='file:///c%3A/Users/colli/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=1663'>1664</a>     if len(data) > 0:
#    <a href='file:///c%3A/Users/colli/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=1664'>1665</a>         # TODO speed up Series case
# -> <a href='file:///c%3A/Users/colli/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=1665'>1666</a>         if isinstance(list(data.values())[0], (Series, dict)):
#    <a href='file:///c%3A/Users/colli/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=1666'>1667</a>             data = _from_nested_dict(data)
#    <a href='file:///c%3A/Users/colli/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/frame.py?line=1667'>1668</a>         else:
#
# AttributeError: 'str' object has no attribute 'values'

# %%
dict
# Out:
# '{"boundingBox":{"lr":{"lng":-154,"lat":15},"ul":{"lng":-179,"lat":29}},"hostedData":[{"extraCriteria":"","columnNames":[],"tableName":"mqap.33454_DunkinDonuts"}],"resultsCount":13,"totalPages":1,"options":{"kmlStyleUrl":"http://search-b2b.cloud.mapquest.com/kml-default.kml","shapeFormat":"raw","maxMatches":4000,"pageSize":13,"ambiguities":false,"units":"m","currentPage":1},"searchResults":[{"distanceUnit":"m","distance":0,"name":"Dunkin Donuts","sourceName":"mqap.33454_DunkinDonuts","resultNumber":1,"fields":{"country":"US","sun_delivery_hours":"","gh_active":"","sat_delivery_hours":"","county":"Honolulu","curbside":"N","sat_catering_hours":"","dine_in":"Y","dt_auto_fire":"","turbooven":"N","sat_cs_hours":"","thu_cs_hours":"","mon_cs_hours":"","combostore":"N","sat_hours":"09:00-15:00","state":"HI","tender_agnostic_enabled":"Y","lat":21.33223,"geocodequality":null,"mon_hours":"09:00-15:00","DBI_FEE_HR_LINK":"","mobile_bypass_lane":"N","lng":-157.920363,"loyalty":"N","wed_cs_hours":"","almond":"N","close_reason_cd":"","APPLY_ONLINE":"","catering_flag":"N","ue_active":"","pos_cmc_id":"","wed_dining_hours":"09:00-15:00","beverageonly":"N","tue_cs_hours":"","mon_dining_hours":"09:00-15:00","sun_catering_hours":"","last_updated_datetime":"1637551876000","adl_add_info":"","postal":"96819","ez_active":"","pos_type":"OPC","thu_delivery_hours":"","fri_dining_hours":"09:00-15:00","sun_hours":"09:00-15:00","operation_status_cd":"2","sun_cs_hours":"","club_dunkin":"","city":"Honolulu","wed_delivery_hours":"","thu_catering_hours":"","dunkincardenabled":"N","phonenumber":"--","wed_catering_hours":"","sat_dining_hours":"09:00-15:00","sitetype":"AI","fri_cs_hours":"","kosher":"N","mon_catering_hours":"","drivein":"N","adv_ord":"N","dma_cd":"744","high_vol_brewer":"","tue_delivery_hours":"","tue_dining_hours":"09:00-15:00","mqap_geography":{"latLng":{"lng":-157.920363,"lat":21.33223}},"tue_hours":"09:00-15:00","mqap_id":"3c60a553-f304-485f-b545-dde64dfcec04","website":"https://www.dunkindonuts.com","address":"300 Rodgers Boulevard","dev_status":"","address2":"Daniel K. Inouyet International Airport","sun_dining_hours":"09:00-15:00","tue_catering_hours":"","mobile":"N","fri_catering_hours":"","n":"Dunkin Donuts","thu_hours":"09:00-15:00","fri_hours":"09:00-15:00","co_brander_cd":"HMS","recordid":363583,"walkin_flag":"Y","thu_dining_hours":"09:00-15:00","otg_menu_opt":"","fri_delivery_hours":"","t":null,"dd_active":"","tap_unit":"","lc":"33454002","pm_active":"","wed_hours":"09:00-15:00","wireless":"N","k_cup":"N","mon_delivery_hours":"","faxnumber":"--","next_gen_store":"Y"},"key":"3c60a553-f304-485f-b545-dde64dfcec04","shapePoints":[21.33223,-157.920363]},{"distanceUnit":"m","distance":0,"name":"Dunkin Donuts","sourceName":"mqap.33454_DunkinDonuts","resultNumber":2,"fields":{"country":"US","sun_delivery_hours":"11:00-19:30","gh_active":"Y","sat_delivery_hours":"11:00-19:30","county":"Honolulu","curbside":"N","sat_catering_hours":"","dine_in":"N","dt_auto_fire":"Y","turbooven":"Y","sat_cs_hours":"","thu_cs_hours":"","mon_cs_hours":"","combostore":"N","sat_hours":"06:00-20:00","state":"HI","tender_agnostic_enabled":"Y","lat":21.3348,"geocodequality":null,"mon_hours":"05:00-20:00","DBI_FEE_HR_LINK":"http://www.alohagas.com/employment.html","mobile_bypass_lane":"N","lng":-157.91464,"loyalty":"Y","wed_cs_hours":"","almond":"N","close_reason_cd":"","APPLY_ONLINE":"Y","catering_flag":"N","ue_active":"Y","pos_cmc_id":"1019094","wed_dining_hours":"05:00-20:00","beverageonly":"N","tue_cs_hours":"","mon_dining_hours":"05:00-20:00","sun_catering_hours":"","last_updated_datetime":"1637551876000","adl_add_info":"","postal":"96819","ez_active":"","pos_type":"Simphony","thu_delivery_hours":"11:00-19:30","fri_dining_hours":"05:00-20:00","sun_hours":"06:00-20:00","operation_status_cd":"2","sun_cs_hours":"","club_dunkin":"","city":"Honolulu","wed_delivery_hours":"11:00-19:30","thu_catering_hours":"","dunkincardenabled":"Y","phonenumber":"808-839-7505","wed_cate ...
